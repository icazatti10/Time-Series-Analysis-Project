# %%
import pandas as pd

import os
os.getcwd()
os.chdir(r"C:\Users\ryanc\repo\Time-Series-Analysis-Project")

# %%
df = pd.read_csv("datasources\BogusSnowDaily.csv")
df.head()
# Out:
#         Date  SNWD (in)
# 0  9/23/1999          0
# 1  9/24/1999          0
# 2  9/25/1999          0
# 3  9/26/1999          0
# 4  9/27/1999          0

# %%
from homework.plots.ts_plot import ts_plot
from homework.plots.residual_plot import residual_plot

# %%
ts_plot(df["Date"], df["SNWD (in)"], title = "snow Depth", xlabel = 'date', ylabel = 'snow');
